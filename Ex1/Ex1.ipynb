# %%
import pandas as pd

# %%
df = pd.read_csv("company_data.csv")

# %%
df.head(2)
# Out:
#   Company  Job Degree Salary
# 0  Google  SDE  BTech   High
# 1  Google  SDE  MTech   High

# %%
df.tail(2)
# Out:
#    Company      Job Degree Salary
# 6      TCS  Analyst   BCom    Low
# 7  Infosys   Tester    BSc    Low
